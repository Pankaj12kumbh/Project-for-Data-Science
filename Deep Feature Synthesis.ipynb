# %%
import featuretools as ft

# %%
data = ft.demo.load_mock_customer()

# %%
customers_df = data["customers"]
customers_df
# Out:
#    customer_id zip_code           join_date   birthday
# 0            1    60091 2011-04-17 10:48:33 1994-07-18
# 1            2    13244 2012-04-15 23:31:04 1986-08-18
# 2            3    13244 2011-08-13 15:42:34 2003-11-21
# 3            4    60091 2011-04-08 20:08:14 2006-08-15
# 4            5    60091 2010-07-17 05:27:50 1984-07-28

# %%
sessions_df = data["sessions"]
sessions_df.sample(5)
# Out:
#     session_id  customer_id   device       session_start
# 13          14            1   tablet 2014-01-01 03:28:00
# 6            7            3   tablet 2014-01-01 01:39:40
# 1            2            5   mobile 2014-01-01 00:17:20
# 28          29            1   mobile 2014-01-01 07:10:05
# 24          25            3  desktop 2014-01-01 05:59:40

# %%
transactions_df = data["transactions"]
transactions_df.sample(5)
# Out:
#      transaction_id  session_id    transaction_time product_id  amount
# 74              232           5 2014-01-01 01:20:10          1  139.20
# 231              27          17 2014-01-01 04:10:15          2   90.79
# 434              36          31 2014-01-01 07:50:10          3   62.35
# 420              56          30 2014-01-01 07:35:00          3   72.70
# 54              444           4 2014-01-01 00:58:30          4   43.59

# %%
dataframes = {
    "customers": (customers_df, "customer_id"),
    "sessions": (sessions_df, "session_id", "session_start"),
    "transactions": (transactions_df, "transaction_id", "transaction_time"),
}

# %%
relationships = [
    ("sessions", "session_id", "transactions", "session_id"),
    ("customers", "customer_id", "sessions", "customer_id"),
]

# %%
feature_matrix_customers, features_defs = ft.dfs(
    dataframes=dataframes,
    relationships=relationships,
    target_dataframe_name="customers",
)
feature_matrix_customers
# Out:
#              zip_code  COUNT(sessions) MODE(sessions.device)  \
# customer_id
# 1               60091                8                mobile
# 2               13244                7               desktop
# 3               13244                6               desktop
# 4               60091                8                mobile
# 5               60091                6                mobile
#
#              NUM_UNIQUE(sessions.device)  COUNT(transactions)  \
# customer_id
# 1                                      3                  126
# 2                                      3                   93
# 3                                      3                   93
# 4                                      3                  109
# 5                                      3                   79
#
#              MAX(transactions.amount)  MEAN(transactions.amount)  \
# customer_id
# 1                              139.43                  71.631905
# 2                              146.81                  77.422366
# 3                              149.15                  67.060430
# 4                              149.95                  80.070459
# 5                              149.02                  80.375443
#
#              MIN(transactions.amount) MODE(transactions.product_id)  \
# customer_id
# 1                                5.81                             4
# 2                                8.73                             4
# 3                                5.89                             1
# 4                                5.73                             2
# 5                                7.55                             5
#
#              NUM_UNIQUE(transactions.product_id)  ...  \
# customer_id                                       ...
# 1                                              5  ...
# 2                                              5  ...
# 3                                              5  ...
# 4                                              5  ...
# 5                                              5  ...
#
#              STD(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                           0.589386
# 2                                           0.509798
# 3                                           0.429374
# 4                                           0.387884
# 5                                           0.415426
#
#              STD(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                        279.510713
# 2                                        251.609234
# 3                                        219.021420
# 4                                        235.992478
# 5                                        402.775486
#
#              SUM(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                           1057.97
# 2                                            931.63
# 3                                            847.63
# 4                                           1157.99
# 5                                            839.76
#
#             SUM(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                        582.193117
# 2                                        548.905851
# 3                                        405.237462
# 4                                        649.657515
# 5                                        472.231119
#
#             SUM(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                            78.59
# 2                                           154.60
# 3                                            66.21
# 4                                           131.51
# 5                                            86.49
#
#             SUM(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                        40.0
# 2                                                        35.0
# 3                                                        29.0
# 4                                                        37.0
# 5                                                        30.0
#
#             SUM(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                         -0.476122
# 2                                         -0.277640
# 3                                          2.286086
# 4                                          0.002764
# 5                                          0.014384
#
#             SUM(sessions.STD(transactions.amount))  \
# customer_id
# 1                                       312.745952
# 2                                       258.700528
# 3                                       257.299895
# 4                                       356.125829
# 5                                       259.873954
#
#             MODE(transactions.sessions.device)  \
# customer_id
# 1                                       mobile
# 2                                      desktop
# 3                                      desktop
# 4                                       mobile
# 5                                       mobile
#
#             NUM_UNIQUE(transactions.sessions.device)
# customer_id
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
# 5                                                  3
#
# [5 rows x 75 columns]

# %%
feature_matrix_sessions, features_defs = ft.dfs(
    dataframes=dataframes, relationships=relationships, target_dataframe_name="sessions"
)
feature_matrix_sessions.head(5)
# Out:
# C:\Users\sif-\Ana3\lib\site-packages\featuretools\entityset\entityset.py:754: UserWarning: A Woodwork-initialized DataFrame was provided, so the following parameters were ignored: index
#   warnings.warn(
# C:\Users\sif-\Ana3\lib\site-packages\featuretools\entityset\entityset.py:754: UserWarning: A Woodwork-initialized DataFrame was provided, so the following parameters were ignored: index, time_index
#   warnings.warn(
#             customer_id   device  COUNT(transactions)  \
# session_id
# 1                     2  desktop                   16
# 2                     5   mobile                   10
# 3                     4   mobile                   15
# 4                     1   mobile                   25
# 5                     4   mobile                   11
#
#             MAX(transactions.amount)  MEAN(transactions.amount)  \
# session_id
# 1                             141.66                  76.813125
# 2                             135.25                  74.696000
# 3                             147.73                  88.600000
# 4                             129.00                  64.557200
# 5                             139.20                  70.638182
#
#             MIN(transactions.amount) MODE(transactions.product_id)  \
# session_id
# 1                              20.91                             3
# 2                               9.32                             5
# 3                               8.70                             1
# 4                               6.29                             5
# 5                               7.43                             5
#
#             NUM_UNIQUE(transactions.product_id)  SKEW(transactions.amount)  \
# session_id
# 1                                             5                   0.295458
# 2                                             5                  -0.160550
# 3                                             5                  -0.324012
# 4                                             5                   0.234349
# 5                                             5                   0.336381
#
#             STD(transactions.amount)  ...  customers.STD(transactions.amount)  \
# session_id                            ...
# 1                          41.600976  ...                           37.705178
# 2                          45.893591  ...                           44.095630
# 3                          46.240016  ...                           45.068765
# 4                          40.187205  ...                           40.442059
# 5                          48.918663  ...                           45.068765
#
#            customers.SUM(transactions.amount) customers.DAY(birthday)  \
# session_id
# 1                                     7200.28                      18
# 2                                     6349.66                      28
# 3                                     8727.68                      15
# 4                                     9025.62                      18
# 5                                     8727.68                      15
#
#            customers.DAY(join_date) customers.MONTH(birthday)  \
# session_id
# 1                                15                         8
# 2                                17                         7
# 3                                 8                         8
# 4                                17                         7
# 5                                 8                         8
#
#             customers.MONTH(join_date) customers.WEEKDAY(birthday)  \
# session_id
# 1                                    4                           0
# 2                                    7                           5
# 3                                    4                           1
# 4                                    4                           0
# 5                                    4                           1
#
#            customers.WEEKDAY(join_date) customers.YEAR(birthday)  \
# session_id
# 1                                     6                     1986
# 2                                     5                     1984
# 3                                     4                     2006
# 4                                     6                     1994
# 5                                     4                     2006
#
#            customers.YEAR(join_date)
# session_id
# 1                               2012
# 2                               2010
# 3                               2011
# 4                               2011
# 5                               2011
#
# [5 rows x 44 columns]

# %%
feature = features_defs[18]
feature
# Out:
# <Feature: MODE(transactions.WEEKDAY(transaction_time))>

# %%
from featuretools.primitives import (Minute, Hour, Day, Week, Month,
                                     Weekday, IsWeekend, Count, Sum, Mean, Median, Std, Min, Max)
import numpy as np
ft.__version__
# %load_ext autoreload
# %autoreload 2

# %%
ft.graph_feature(feature)

# %%
data
# Out:
# {'customers':    customer_id zip_code           join_date   birthday
#  0            1    60091 2011-04-17 10:48:33 1994-07-18
#  1            2    13244 2012-04-15 23:31:04 1986-08-18
#  2            3    13244 2011-08-13 15:42:34 2003-11-21
#  3            4    60091 2011-04-08 20:08:14 2006-08-15
#  4            5    60091 2010-07-17 05:27:50 1984-07-28,
#  'sessions':     session_id  customer_id   device       session_start
#  0            1            2  desktop 2014-01-01 00:00:00
#  1            2            5   mobile 2014-01-01 00:17:20
#  2            3            4   mobile 2014-01-01 00:28:10
#  3            4            1   mobile 2014-01-01 00:44:25
#  4            5            4   mobile 2014-01-01 01:11:30
#  5            6            1   tablet 2014-01-01 01:23:25
#  6            7            3   tablet 2014-01-01 01:39:40
#  7            8            4   tablet 2014-01-01 01:55:55
#  8            9            1  desktop 2014-01-01 02:15:25
#  9           10            2   tablet 2014-01-01 02:31:40
#  10          11            4   mobile 2014-01-01 02:47:55
#  11          12            4  desktop 2014-01-01 03:04:10
#  12          13            4   mobile 2014-01-01 03:15:00
#  13          14            1   tablet 2014-01-01 03:28:00
#  14          15            2  desktop 2014-01-01 03:41:00
#  15          16            2  desktop 2014-01-01 03:49:40
#  16          17            2   tablet 2014-01-01 04:00:30
#  17          18            1  desktop 2014-01-01 04:14:35
#  18          19            3  desktop 2014-01-01 04:27:35
#  19          20            5  desktop 2014-01-01 04:46:00
#  20          21            4  desktop 2014-01-01 05:02:15
#  21          22            4  desktop 2014-01-01 05:21:45
#  22          23            3  desktop 2014-01-01 05:32:35
#  23          24            5   tablet 2014-01-01 05:44:30
#  24          25            3  desktop 2014-01-01 05:59:40
#  25          26            1   tablet 2014-01-01 06:17:00
#  26          27            1   mobile 2014-01-01 06:34:20
#  27          28            5   mobile 2014-01-01 06:50:35
#  28          29            1   mobile 2014-01-01 07:10:05
#  29          30            5  desktop 2014-01-01 07:27:25
#  30          31            2   mobile 2014-01-01 07:42:35
#  31          32            5   mobile 2014-01-01 08:02:05
#  32          33            2   mobile 2014-01-01 08:10:45
#  33          34            3  desktop 2014-01-01 08:24:50
#  34          35            3   mobile 2014-01-01 08:44:20,
#  'transactions':      transaction_id  session_id    transaction_time product_id  amount
#  0               298           1 2014-01-01 00:00:00          5  127.64
#  1                 2           1 2014-01-01 00:01:05          2  109.48
#  2               308           1 2014-01-01 00:02:10          3   95.06
#  3               116           1 2014-01-01 00:03:15          4   78.92
#  4               371           1 2014-01-01 00:04:20          3   31.54
#  ..              ...         ...                 ...        ...     ...
#  495             112          35 2014-01-01 08:56:15          5   55.42
#  496             111          35 2014-01-01 08:57:20          3   34.87
#  497             276          35 2014-01-01 08:58:25          1   10.94
#  498             266          35 2014-01-01 08:59:30          5   19.86
#  499             203          35 2014-01-01 09:00:35          3  148.31
#
#  [500 rows x 5 columns],
#  'products':   product_id brand
#  0          1     B
#  1          2     B
#  2          3     B
#  3          4     B
#  4          5     A}

# %%
es = ft.demo.load_mock_customer(return_entityset=True)
es
# Out:
# Entityset: transactions
#   DataFrames:
#     transactions [Rows: 500, Columns: 6]
#     products [Rows: 5, Columns: 3]
#     sessions [Rows: 35, Columns: 5]
#     customers [Rows: 5, Columns: 5]
#   Relationships:
#     transactions.product_id -> products.product_id
#     transactions.session_id -> sessions.session_id
#     sessions.customer_id -> customers.customer_id

# %%
feature_matrix, feature_defs = ft.dfs(
    entityset=es,
    target_dataframe_name="customers",
    agg_primitives=["count"],
    trans_primitives=["month"],
    max_depth=1,
)
feature_matrix
# Out:
#             zip_code  COUNT(sessions) MONTH(birthday) MONTH(join_date)
# customer_id
# 5              60091                6               7                7
# 4              60091                8               8                4
# 1              60091                8               7                4
# 3              13244                6              11                8
# 2              13244                7               8                4

# %%
feature_matrix, feature_defs = ft.dfs(
    entityset=es,
    target_dataframe_name="customers",
    agg_primitives=["mean", "sum", "mode"],
    trans_primitives=["month", "hour"],
    max_depth=2,
)
feature_matrix
# Out:
#             zip_code MODE(sessions.device)  MEAN(transactions.amount)  \
# customer_id
# 5              60091                mobile                  80.375443
# 4              60091                mobile                  80.070459
# 1              60091                mobile                  71.631905
# 3              13244               desktop                  67.060430
# 2              13244               desktop                  77.422366
#
#             MODE(transactions.product_id)  SUM(transactions.amount)  \
# customer_id
# 5                                       5                   6349.66
# 4                                       2                   8727.68
# 1                                       4                   9025.62
# 3                                       1                   6236.62
# 2                                       4                   7200.28
#
#             HOUR(birthday) HOUR(join_date) MONTH(birthday) MONTH(join_date)  \
# customer_id
# 5                        0               5               7                7
# 4                        0              20               8                4
# 1                        0              10               7                4
# 3                        0              15              11                8
# 2                        0              23               8                4
#
#              MEAN(sessions.MEAN(transactions.amount))  \
# customer_id
# 5                                           78.705187
# 4                                           81.207189
# 1                                           72.774140
# 3                                           67.539577
# 2                                           78.415122
#
#              MEAN(sessions.SUM(transactions.amount))  \
# customer_id
# 5                                        1058.276667
# 4                                        1090.960000
# 1                                        1128.202500
# 3                                        1039.436667
# 2                                        1028.611429
#
#             MODE(sessions.HOUR(session_start))  \
# customer_id
# 5                                            0
# 4                                            1
# 1                                            6
# 3                                            5
# 2                                            3
#
#             MODE(sessions.MODE(transactions.product_id))  \
# customer_id
# 5                                                      3
# 4                                                      1
# 1                                                      4
# 3                                                      1
# 2                                                      3
#
#             MODE(sessions.MONTH(session_start))  \
# customer_id
# 5                                             1
# 4                                             1
# 1                                             1
# 3                                             1
# 2                                             1
#
#              SUM(sessions.MEAN(transactions.amount))  \
# customer_id
# 5                                         472.231119
# 4                                         649.657515
# 1                                         582.193117
# 3                                         405.237462
# 2                                         548.905851
#
#             MODE(transactions.sessions.device)
# customer_id
# 5                                       mobile
# 4                                       mobile
# 1                                       mobile
# 3                                      desktop
# 2                                      desktop

# %%
feature_matrix.dtypes
# Out:
# zip_code                                        category
# MODE(sessions.device)                           category
# MEAN(transactions.amount)                        float64
# MODE(transactions.product_id)                   category
# SUM(transactions.amount)                         float64
# HOUR(birthday)                                  category
# HOUR(join_date)                                 category
# MONTH(birthday)                                 category
# MONTH(join_date)                                category
# MEAN(sessions.MEAN(transactions.amount))         float64
# MEAN(sessions.SUM(transactions.amount))          float64
# MODE(sessions.HOUR(session_start))              category
# MODE(sessions.MODE(transactions.product_id))    category
# MODE(sessions.MONTH(session_start))             category
# SUM(sessions.MEAN(transactions.amount))          float64
# MODE(transactions.sessions.device)              category
# dtype: object

# %%
feature_matrix[["MEAN(sessions.SUM(transactions.amount))","MODE(sessions.HOUR(session_start))"]]
# Out:
#              MEAN(sessions.SUM(transactions.amount))  \
# customer_id
# 5                                        1058.276667
# 4                                        1090.960000
# 1                                        1128.202500
# 3                                        1039.436667
# 2                                        1028.611429
#
#             MODE(sessions.HOUR(session_start))
# customer_id
# 5                                            0
# 4                                            1
# 1                                            6
# 3                                            5
# 2                                            3
